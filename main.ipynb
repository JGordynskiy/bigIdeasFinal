# %% [markdown]
# Best communities in Pittsburgh

# %%
import pandas as pd

# %matplotlib inline

# %%
data = pd.read_csv("parks.csv")
dataP = data["neighborhood"].value_counts()
print (dataP)
# Out:
# neighborhood
# East Liberty                 12
# Central Business District    10
# Beechview                     8
# South Side Slopes             7
# Point Breeze                  7
#                              ..
# Upper Hill                    1
# West Oakland                  1
# Bluff                         1
# Middle Hill                   1
# Squirrel Hill North           1
# Name: count, Length: 73, dtype: int64

# %% [markdown]
# East Liberty has the most parks out of all of the neighborhoods in Pittsburgh with 12.
