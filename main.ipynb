# %% [markdown]
# Best communities in Pittsburgh

# %%
import pandas as pd

# %matplotlib inline

# %%
data = pd.read_csv("parks.csv")
data.pivot(columns="name", values="attendance_count").head()
data.groupby("neighborhood").count()
# Out:
# name Able Long Park Albert Turk Graham Park   Alcoa Park Allegheny Commons  \
# 0         Beechview                     NaN          NaN               NaN
# 1               NaN        Crawford-Roberts          NaN               NaN
# 2               NaN                     NaN  North Shore               NaN
# 3               NaN                     NaN          NaN  Allegheny Center
# 4               NaN                     NaN          NaN               NaN
#
# name Allegheny Landing Park Allegheny Riverfront Park Alpine Gardens Park  \
# 0                       NaN                       NaN                 NaN
# 1                       NaN                       NaN                 NaN
# 2                       NaN                       NaN                 NaN
# 3                       NaN                       NaN                 NaN
# 4               North Shore                       NaN                 NaN
#
# name Alton Park Amber Triangle Ammon Park  ... West Penn Park  \
# 0           NaN            NaN        NaN  ...            NaN
# 1           NaN            NaN        NaN  ...            NaN
# 2           NaN            NaN        NaN  ...            NaN
# 3           NaN            NaN        NaN  ...            NaN
# 4           NaN            NaN        NaN  ...            NaN
#
# name Westinghouse Park Westwood Island Westwood School Park Wightman Park  \
# 0                  NaN             NaN                  NaN           NaN
# 1                  NaN             NaN                  NaN           NaN
# 2                  NaN             NaN                  NaN           NaN
# 3                  NaN             NaN                  NaN           NaN
# 4                  NaN             NaN                  NaN           NaN
#
# name Windermere Circle 1 & 2 Winters Park Woods Run Park Young Field Park  \
# 0                        NaN          NaN            NaN              NaN
# 1                        NaN          NaN            NaN              NaN
# 2                        NaN          NaN            NaN              NaN
# 3                        NaN          NaN            NaN              NaN
# 4                        NaN          NaN            NaN              NaN
#
# name Zulema Park
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 209 columns]
